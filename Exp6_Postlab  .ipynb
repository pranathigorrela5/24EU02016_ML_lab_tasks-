# %%
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

df = sns.load_dataset("titanic")

X = df[["survived", "pclass", "age", "fare"]].copy()
X["age"] = X["age"].fillna(X["age"].median())

X_scaled = StandardScaler().fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("PCA Result:")
print(X_pca)
print("Explained Variance:", pca.explained_variance_ratio_)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c="blue")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("24EU02016-PCA Graph - Titanic Dataset")
plt.show()
# Out:
# PCA Result:
# [[ 1.31115196 -0.02755857]
#  [-2.17620413 -0.12212928]
#  [ 0.37498766 -0.96973492]
#  ...
#  [ 0.98941929  0.30101217]
#  [-1.43017092 -0.75724409]
#  [ 1.08090364  0.58576765]]
# Explained Variance: [0.46322496 0.26984842]

# %%
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

df = sns.load_dataset("titanic")

X = df[["survived", "pclass", "age", "fare"]].copy()
X["age"] = X["age"].fillna(X["age"].median())

X_scaled = StandardScaler().fit_transform(X)

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_scaled)



plt.scatter(X["age"], X["fare"], c=clusters)
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("24EU02016-K-Means Clustering")
plt.show()
